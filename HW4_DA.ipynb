# %%
import pandas as pd
df_public = pd.read_csv("survey_results_public.csv")
df1_schema = pd.read_csv("survey_results_schema.csv")

# %%
display(df_public,df1_schema)
# Out:
#        ResponseId                      MainBranch                 Age  \
# 0               1  I am a developer by profession  Under 18 years old
# 1               2  I am a developer by profession     35-44 years old
# 2               3  I am a developer by profession     45-54 years old
# 3               4           I am learning to code     18-24 years old
# 4               5  I am a developer by profession     18-24 years old
# ...           ...                             ...                 ...
# 65432       65433  I am a developer by profession     18-24 years old
# 65433       65434  I am a developer by profession     25-34 years old
# 65434       65435  I am a developer by profession     25-34 years old
# 65435       65436  I am a developer by profession     18-24 years old
# 65436       65437     I code primarily as a hobby     18-24 years old
#
#                 Employment                            RemoteWork   Check  \
# ...

# %%
df1_schema.head(10)
# Out:
#       qid             qname  \
# 0    QID2        MainBranch
# 1  QID127               Age
# 2  QID296        Employment
# 3  QID308        RemoteWork
# 4  QID341             Check
# 5  QID297  CodingActivities
# 6   QID25           EdLevel
# 7  QID276         LearnCode
# 8  QID281   LearnCodeOnline
# 9  QID331           TechDoc
#
#                                             question force_resp type selector
# 0  Which of the following options best describes ...       True   MC     SAVR
# 1                                 What is your age?*       True   MC     SAVR
# 2  Which of the following best describes your cur...       True   MC     MAVR
# 3  Which best describes your current work situation?      False   MC     SAVR
# 4  Just checking to make sure you are paying atte...       True   MC     SAVR
# 5  Which of the following best describes the code...      False   MC     MAVR
# 6  Which of the following best describes the high...       True   MC     SAVR
# ...

# %%
df_public.head(3)
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
#
#                                            EdLevel  \
# 0                        Primary/elementary school
# 1     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                                            LearnCode  \
# ...

# %%
print(df_public.columns.tolist())
# Out:
# ['ResponseId', 'MainBranch', 'Age', 'Employment', 'RemoteWork', 'Check', 'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline', 'TechDoc', 'YearsCode', 'YearsCodePro', 'DevType', 'OrgSize', 'PurchaseInfluence', 'BuyNewTool', 'BuildvsBuy', 'TechEndorse', 'Country', 'Currency', 'CompTotal', 'LanguageHaveWorkedWith', 'LanguageWantToWorkWith', 'LanguageAdmired', 'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith', 'DatabaseAdmired', 'PlatformHaveWorkedWith', 'PlatformWantToWorkWith', 'PlatformAdmired', 'WebframeHaveWorkedWith', 'WebframeWantToWorkWith', 'WebframeAdmired', 'EmbeddedHaveWorkedWith', 'EmbeddedWantToWorkWith', 'EmbeddedAdmired', 'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith', 'MiscTechAdmired', 'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith', 'ToolsTechAdmired', 'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith', 'NEWCollabToolsAdmired', 'OpSysPersonal use', 'OpSysProfessional use', 'OfficeStackAsyncHaveWorkedWith', 'OfficeStackAsyncWantToWorkWith
# ...

# %%
df1_schema.columns
# Out:
# Index(['qid', 'qname', 'question', 'force_resp', 'type', 'selector'], dtype='object')

# %%
df1_schema.head(10)
# Out:
#       qid             qname  \
# 0    QID2        MainBranch
# 1  QID127               Age
# 2  QID296        Employment
# 3  QID308        RemoteWork
# 4  QID341             Check
# 5  QID297  CodingActivities
# 6   QID25           EdLevel
# 7  QID276         LearnCode
# 8  QID281   LearnCodeOnline
# 9  QID331           TechDoc
#
#                                             question force_resp type selector
# 0  Which of the following options best describes ...       True   MC     SAVR
# 1                                 What is your age?*       True   MC     SAVR
# 2  Which of the following best describes your cur...       True   MC     MAVR
# 3  Which best describes your current work situation?      False   MC     SAVR
# 4  Just checking to make sure you are paying atte...       True   MC     SAVR
# 5  Which of the following best describes the code...      False   MC     MAVR
# 6  Which of the following best describes the high...       True   MC     SAVR
# ...

# %%
df_public.ResponseId.nunique() #1. Скільки респондентів пройшли опитування
# Out:
# 65437

# %%
df_public.shape
# Out:
# (65437, 114)

# %%
question = set(df1_schema.qname.unique()) & set(df_public.columns)
df_public.dropna(subset=question).shape[0] # 2. Скільки респондентів відповіли на всі запитання
# Out:
# 6306

# %%
df_public.WorkExp.mean()
# Out:
# 11.46695663901814

# %%
print(f'Mean: {round(df_public.WorkExp.mean(),2)}') #3. Яке значення міри центральної тенденції для досвіду (WorkExp) респондентів
print(f'Mode: {round(df_public.WorkExp.mode(),2)}')
print(f'Median: {round(df_public.WorkExp.median(),2)}')
# Out:
# Mean: 11.47
# Mode: 0    3.0
# Name: WorkExp, dtype: float64
# Median: 9.0

# %%
df_public[df_public.RemoteWork == 'Remote'].shape[0] 
#4. Скільки респондентів працює віддалено
# Out:
# 65437

# %% [markdown]
# 5. Який відсоток респондентів програмується на Pythonyton

# %%
df_public.LanguageHaveWorkedWith.str.contains('python', case=False, na=False)
# Out:
# 0        False
# 1         True
# 2        False
# 3         True
# 4         True
#          ...
# 65432    False
# 65433    False
# 65434    False
# 65435     True
# 65436     True
# Name: LanguageHaveWorkedWith, Length: 65437, dtype: bool

# %% [markdown]
# user_python_persent=round(sum(df_public.LanguageHaveWorkedWith.str.contains('python', case=False, na=False)) / (df_public.ResponseId.nunique())*100, 2)
# user_python_persent

# %%
sum(df_public.LanguageHaveWorkedWith.str.contains('python', case=False, na=False))
# Out:
# 30795

# %% [markdown]
# 6. Скільки респондентів навчалося програмувати за допомогою онлайн-курсів

# %%
sum(df_public.LearnCode.str.contains('online courses', case=False, na=False))
# Out:
# 30271

# %%
df_public.LearnCode.str.contains('online courses', case=False, na=False)
# Out:
# 0        False
# 1        False
# 2        False
# 3         True
# 4        False
#          ...
# 65432    False
# 65433    False
# 65434    False
# 65435    False
# 65436    False
# Name: LearnCode, Length: 65437, dtype: bool

# %% [markdown]
# 7. Серед респондентів, які програмують на Python в групуванні по країнах, яка середня та медіанна сума компенсації (ConvertedCompYearly) в кожній країні?

# %%
df_python = df_public.LanguageHaveWorkedWith.str.contains('python', case=False, na=False)
df_python
# Out:
# 0        False
# 1         True
# 2        False
# 3         True
# 4         True
#          ...
# 65432    False
# 65433    False
# 65434    False
# 65435     True
# 65436     True
# Name: LanguageHaveWorkedWith, Length: 65437, dtype: bool

# %%
df_ConvertedCompYearly = df[df_python == 1].dropna(subset='ConvertedCompYearly') \
                                            .groupby('Country', as_index=False) \
                                            .agg({'ConvertedCompYearly':['mean','median']})

# %%
df_ConvertedCompYearly
# Out:
#                                   Country ConvertedCompYearly
#                                                          mean    median
# 0                             Afghanistan         4543.000000    4768.5
# 1                                 Albania        56295.000000   56295.0
# 2                                 Algeria         9053.285714    6230.0
# 3                                 Andorra       193331.000000  193331.0
# 4                                  Angola            6.000000       6.0
# ..                                    ...                 ...       ...
# 146  Venezuela, Bolivarian Republic of...        21500.000000    7100.0
# 147                              Viet Nam        14014.562500   10180.0
# 148                                 Yemen        10297.333333    5333.0
# 149                                Zambia        28123.666667   22803.0
# 150                              Zimbabwe        37500.000000   18000.0
#
# [151 rows x 3 columns]

# %% [markdown]
# 8. Які рівні освіти мають 5 респондентів з найбільшою компенсацією?

# %%
df_public[['ResponseId','EdLevel','ConvertedCompYearly']].sort_values(by='ConvertedCompYearly', ascending=False).reset_index(drop=True).head(5)
# Out:
#    ResponseId                                         EdLevel  \
# 0       15838    Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 1       12724  Professional degree (JD, MD, Ph.D, Ed.D, etc.)
# 2       28380  Professional degree (JD, MD, Ph.D, Ed.D, etc.)
# 3       17594    Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4       17673  Professional degree (JD, MD, Ph.D, Ed.D, etc.)
#
#    ConvertedCompYearly
# 0           16256603.0
# 1           13818022.0
# 2            9000000.0
# 3            6340564.0
# 4            4936778.0

# %% [markdown]
# 1. У кожній віковій категорії, який відсоток респондентів програмується на Python?

# %%
df_python = df_public.LanguageHaveWorkedWith.str.contains('python', case=False, na=False)
df_python
# Out:
# 0        False
# 1         True
# 2        False
# 3         True
# 4         True
#          ...
# 65432    False
# 65433    False
# 65434    False
# 65435     True
# 65436     True
# Name: LanguageHaveWorkedWith, Length: 65437, dtype: bool

# %%
# Створюємо маску для Python
df["Uses_Python"] = df["LanguageHaveWorkedWith"].str.contains("python", case=False, na=False)

# Рахуємо загальну кількість респондентів у кожній віковій категорії
age_counts = df.groupby("Age").size()

# Рахуємо, скільки з них працює з Python
python_counts = df.groupby("Age")["Uses_Python"].sum()

# Обчислюємо відсоток
df_python_percentage = (python_counts / age_counts * 100).reset_index(name="Python_Percentage")

# Виводимо результат
print(df_python_percentage)
# Out:
#                   Age  Python_Percentage
# 0     18-24 years old          55.922826
# 1     25-34 years old          45.773912
# 2     35-44 years old          41.520546
# 3     45-54 years old          41.910706
# 4     55-64 years old          40.427184
# 5   65 years or older          37.564767
# 6   Prefer not to say          45.341615
# 7  Under 18 years old          64.875389
